# %% [markdown]
# Analysis for the weather in terms of latitude or the distance from the equator:

# %% [markdown]
# From the plotting of the graphs, the points are equally spaced corresponding to the cities across the world, both northern and southern hemisphere.

# %% [markdown]
# The temperature graph shows a clear markdown of higher temperatures closer to the equator at the present time. This data can vary with seasons as the northern hemisphere is more inclined towards the sun during certain times of the year and vice versa with the Southern hemisphere (Not shown).

# %% [markdown]
# The humidity, cloudiness and wind speed has little or significance in terms of correlation with Latitude. However, it is important to note that during winter months, the wind chill factor is significant in terms of temperature. So, it is indirectly related to temperature making the areas farther from the equator colder. This is not shown in the following graphical analysis.

# %% [markdown]
# Overall conclusion from the data analysis reveals that it is warmer as you approach the equator.

# %% [markdown]
# - Deepa Karnani

# %%
#Dependencies#Depend 
from citipy import citipy
from config import openweatherkey
import random
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import requests
import json
import gzip
import unidecode
import time
from config import openweatherkey

# %%
# Build data frame of randomly generated lat and long
coordinates = pd.DataFrame()
coordinates['lat_dist'] = np.random.uniform(-90,90, 1700)
coordinates['lng_dist'] = np.random.uniform(-180, 180, 1700)

coordinates.to_csv("Output/Weatherdata")

# %%
# Call citipy file to get nearest city based on random lat and lng
# add closest city and country column
coordinates['closest_city'] = ""
coordinates['country'] = ""

#find and add closest city and country code
for index, row in coordinates.iterrows():
    lat = row['lat_dist']
    lng = row['lng_dist']
    coordinates.set_value(index, 'closest_city', citipy.nearest_city(lat, lng).city_name)
    coordinates.set_value(index, 'country', citipy.nearest_city(lat, lng).country_code)
# Out:
# C:\Users\dinot\AppData\Local\conda\conda\envs\pythondata\lib\site-packages\ipykernel_launcher.py:10: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   # Remove the CWD from sys.path while we load stuff.
# C:\Users\dinot\AppData\Local\conda\conda\envs\pythondata\lib\site-packages\ipykernel_launcher.py:11: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   # This is added back by InteractiveShellApp.init_path()

# %%
    
# Test to see if the random city is already in the list, if not, add it to the city and country lists
# delete repeated cities and find unique city count
coordinates = coordinates.drop_duplicates(['closest_city', 'country'])
coordinates = coordinates.dropna()
len(coordinates['closest_city'].value_counts())
# Out:
# 681

# %%
coordinates = coordinates[['closest_city', 'country']]
coordinates.head()
# Out:
#   closest_city country
# 0  new norfolk      au
# 1   butaritari      ki
# 2    taolanaro      mg
# 3       knysna      za
# 4    sembabule      ug

# %%
#rename column
coordinates = coordinates.rename(columns = {'closest_city': 'city'})

for index, row in coordinates.iterrows():
    upcase_country = row['country'].upper() # make all two digit country codes capital
    coordinates.set_value(index, 'country', upcase_country) # reset the value of country to uppercase
    cap_city = row['city'].title() # make all city codes capital
    coordinates.set_value(index, 'city', cap_city) # reset the value
    unaccented = unidecode.unidecode(cap_city) # strip accents from city name
    coordinates.set_value(index, 'city', unaccented) # reset the value of name (city) to stripped down version
# Out:
# C:\Users\dinot\AppData\Local\conda\conda\envs\pythondata\lib\site-packages\ipykernel_launcher.py:7: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   import sys
# C:\Users\dinot\AppData\Local\conda\conda\envs\pythondata\lib\site-packages\ipykernel_launcher.py:9: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   if __name__ == '__main__':
# C:\Users\dinot\AppData\Local\conda\conda\envs\pythondata\lib\site-packages\ipykernel_launcher.py:11: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   # This is added back by InteractiveShellApp.init_path()

# %%
coordinates.head()
# Out:
#           city country
# 0  New Norfolk      AU
# 1   Butaritari      KI
# 2    Taolanaro      MG
# 3       Knysna      ZA
# 4    Sembabule      UG

# %%
# downloaded from http://openweathermap.org/help/city_list.txt
cities_id = pd.DataFrame()
cities_id = pd.read_csv("city_id_list.csv")
cities_id.head()
cities_id.dtypes
# Out:
# id               int64
# nm              object
# lat            float64
# lon            float64
# countryCode     object
# dtype: object

# %%
# with gzip.open("city.list.json.gz", "rb") as f:
#     citi_data = json.loads(f.read().decode("ansi"))
# #     citi_df = pd.DataFrame([citi_data])

#rename columns

cities_id = cities_id.rename(columns = {'nm': 'city', 'countryCode': 'country'})

#merge data and clean
merged_df = coordinates.merge(cities_id, how = 'left', on = ('city', 'country'))
merged_df = merged_df.drop_duplicates(['city', 'country'])
merged_df = merged_df.dropna()
merged_df['id'] = merged_df['id'].round(0).astype('int')
merged_df.head()
# merged_df.dtypes
# Out:
#              city country       id        lat         lon
# 0     New Norfolk      AU  2155415 -42.782612  147.058701
# 3          Knysna      ZA   988698 -34.036270   23.047131
# 4       Sembabule      UG   226361  -0.077220   31.456671
# 5  Saint-Philippe      RE   935215 -21.358521   55.767948
# 7          Beloha      MG  1067565 -25.166670   45.049999

# %%
#verifying count
# merged_df.reset_index()
merged_df.set_index('id')
merged_df.head()
# Out:
#              city country       id        lat         lon
# 0     New Norfolk      AU  2155415 -42.782612  147.058701
# 3          Knysna      ZA   988698 -34.036270   23.047131
# 4       Sembabule      UG   226361  -0.077220   31.456671
# 5  Saint-Philippe      RE   935215 -21.358521   55.767948
# 7          Beloha      MG  1067565 -25.166670   45.049999

# %%
#leave merged_df the same from here on
weather_data = merged_df.copy()

# %%
# Open Weather Maps Api example links for reference
# id url example: 'api.openweathermap.org/data/2.5/weather?id=2172797'
# remember to use &appid= for key
counter = 0 #for breaking and pausing
current_error_list = [] # for cities without data from current weather
current_errors = 0  #current weather pull errors

# %%
#at time of pull
weather_data['current_temp'] = ""
weather_data['current_humidity'] = ""
weather_data['current_clouds'] = ""
weather_data['current_wind'] = ""
params = {"key": openweatherkey}
param = {"key": openweatherkey}

# %%
t0 = time.time() #for pause timer
for index, row in weather_data.iterrows():
    time.sleep(1)
    base_url = "https://api.openweathermap.org/data/2.5/weather?id="
    units = "Imperial"
    city_id = row['id']

    # update address key value
    params['address'] = f"{city_id}"

   
  
    # convert to json
    
#     country_city = country_city.json()

    query_url = base_url + str(city_id) +"&appid=" + openweatherkey + "&units=" + units
    print('Now retrieving data for city id #%s:%s %s, %s' % (index, row['id'], row['city'], row['country']))
    try: 
        if row['id'] != 0: # use if if ID exists
#         current_url = 'https://api.openweathermap.org/data/2.5/weather?id=%s&APPID=%s&units=imperial' % (loc_id, wkey)
            cities_data = requests.get(query_url, params=params)
            cities_data = cities_data.json()
            weather_data.loc[index, 'current_temp'] = cities_data['main']['temp']
            weather_data.loc[index, 'current_humidity'] = cities_data['main']['humidity']
            weather_data.loc[index, 'current_clouds'] = cities_data['clouds']['all']
            weather_data.loc[index, 'current_wind'] = cities_data['wind']['speed']
        else: #use city and country if no id AND no coordinates
#        
           print(cities_data.url + str('Missing Current Weather Info for city'))
     
    except:
#         print('Missing Current Weather Info for city #%s:%s %s, %s' % (index, row['id'], row['city'], row['country']))
        current_error_list.append(index)
        current_errors += 1
    
    
    print('---------------------------------------------------------------------------')
    print("Now retieving city # " + str(counter))
    print(query_url)
    counter +=1
    if counter % 10 == 0: #because two records pulled for each city 
        t1 = time.time() #records time very 30 records
        sl_time = 90 - (t1-t0) # calculates buffer for api pull limit
        print("")
        print('********Sleeping for %s seconds.********' % (sl_time))
        print("")
        time.sleep(sl_time) # pauses for appropraite amount of time
        t0 = time.time() # resets for next 30 pull timer
#     if counter == 5:
#         break
# Out:
# Now retrieving data for city id #0:2155415 New Norfolk, AU
# ---------------------------------------------------------------------------
# Now retieving city # 0
# https://api.openweathermap.org/data/2.5/weather?id=2155415&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #3:988698 Knysna, ZA
# ---------------------------------------------------------------------------
# Now retieving city # 1
# https://api.openweathermap.org/data/2.5/weather?id=988698&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #4:226361 Sembabule, UG
# ---------------------------------------------------------------------------
# Now retieving city # 2
# https://api.openweathermap.org/data/2.5/weather?id=226361&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #5:935215 Saint-Philippe, RE
# ---------------------------------------------------------------------------
# Now retieving city # 3
# https://api.openweathermap.org/data/2.5/weather?id=935215&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #7:1067565 Beloha, MG
# ---------------------------------------------------------------------------
# Now retieving city # 4
# https://api.openweathermap.org/data/2.5/weather?id=1067565&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #8:2618795 Klaksvik, FO
# ---------------------------------------------------------------------------
# Now retieving city # 5
# https://api.openweathermap.org/data/2.5/weather?id=2618795&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #10:2014833 Tura, RU
# ---------------------------------------------------------------------------
# Now retieving city # 6
# https://api.openweathermap.org/data/2.5/weather?id=2014833&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #11:2075265 Busselton, AU
# ---------------------------------------------------------------------------
# Now retieving city # 7
# https://api.openweathermap.org/data/2.5/weather?id=2075265&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #12:2074865 Carnarvon, AU
# ---------------------------------------------------------------------------
# Now retieving city # 8
# https://api.openweathermap.org/data/2.5/weather?id=2074865&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #13:1224061 Wattegama, LK
# ---------------------------------------------------------------------------
# Now retieving city # 9
# https://api.openweathermap.org/data/2.5/weather?id=1224061&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
#
# ********Sleeping for 77.77541589736938 seconds.********
#
# Now retrieving data for city id #15:3374210 Sao Filipe, CV
# ---------------------------------------------------------------------------
# Now retieving city # 10
# https://api.openweathermap.org/data/2.5/weather?id=3374210&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #18:3893629 Coquimbo, CL
# ---------------------------------------------------------------------------
# Now retieving city # 11
# https://api.openweathermap.org/data/2.5/weather?id=3893629&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #19:1006984 East London, ZA
# ---------------------------------------------------------------------------
# Now retieving city # 12
# https://api.openweathermap.org/data/2.5/weather?id=1006984&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #21:1518139 Tobol, KZ
# ---------------------------------------------------------------------------
# Now retieving city # 13
# https://api.openweathermap.org/data/2.5/weather?id=1518139&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #22:3833367 Ushuaia, AR
# ---------------------------------------------------------------------------
# Now retieving city # 14
# https://api.openweathermap.org/data/2.5/weather?id=3833367&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #23:2092164 Lorengau, PG
# ---------------------------------------------------------------------------
# Now retieving city # 15
# https://api.openweathermap.org/data/2.5/weather?id=2092164&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #26:584991 Suraabad, AZ
# ---------------------------------------------------------------------------
# Now retieving city # 16
# https://api.openweathermap.org/data/2.5/weather?id=584991&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #27:4229763 Waycross, US
# ---------------------------------------------------------------------------
# Now retieving city # 17
# https://api.openweathermap.org/data/2.5/weather?id=4229763&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #29:964432 Port Alfred, ZA
# ---------------------------------------------------------------------------
# Now retieving city # 18
# https://api.openweathermap.org/data/2.5/weather?id=964432&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #30:2077963 Albany, AU
# ---------------------------------------------------------------------------
# Now retieving city # 19
# https://api.openweathermap.org/data/2.5/weather?id=2077963&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
#
# ********Sleeping for 77.96045994758606 seconds.********
#
# Now retrieving data for city id #32:3416888 Grindavik, IS
# ---------------------------------------------------------------------------
# Now retieving city # 20
# https://api.openweathermap.org/data/2.5/weather?id=3416888&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #34:3652764 Puerto Ayora, EC
# ---------------------------------------------------------------------------
# Now retieving city # 21
# https://api.openweathermap.org/data/2.5/weather?id=3652764&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #36:3370903 Jamestown, SH
# ---------------------------------------------------------------------------
# Now retieving city # 22
# https://api.openweathermap.org/data/2.5/weather?id=3370903&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #37:6100069 Peace River, CA
# ---------------------------------------------------------------------------
# Now retieving city # 23
# https://api.openweathermap.org/data/2.5/weather?id=6100069&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #38:4200671 Hinesville, US
# ---------------------------------------------------------------------------
# Now retieving city # 24
# https://api.openweathermap.org/data/2.5/weather?id=4200671&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #39:3874787 Punta Arenas, CL
# ---------------------------------------------------------------------------
# Now retieving city # 25
# https://api.openweathermap.org/data/2.5/weather?id=3874787&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #40:542133 Krasnoyarskiy, RU
# ---------------------------------------------------------------------------
# Now retieving city # 26
# https://api.openweathermap.org/data/2.5/weather?id=542133&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #41:1812256 Dongsheng, CN
# ---------------------------------------------------------------------------
# Now retieving city # 27
# https://api.openweathermap.org/data/2.5/weather?id=1812256&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #44:2405038 Motema, SL
# ---------------------------------------------------------------------------
# Now retieving city # 28
# https://api.openweathermap.org/data/2.5/weather?id=2405038&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #45:1626542 Sorong, ID
# ---------------------------------------------------------------------------
# Now retieving city # 29
# https://api.openweathermap.org/data/2.5/weather?id=1626542&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
#
# ********Sleeping for 77.89732623100281 seconds.********
# Now retrieving data for city id #47:1214488 Meulaboh, ID
# ---------------------------------------------------------------------------
# Now retieving city # 30
# https://api.openweathermap.org/data/2.5/weather?id=1214488&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #48:964420 Port Elizabeth, ZA
# ---------------------------------------------------------------------------
# Now retieving city # 31
# https://api.openweathermap.org/data/2.5/weather?id=964420&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #49:4032243 Vaini, TO
# ---------------------------------------------------------------------------
# Now retieving city # 32
# https://api.openweathermap.org/data/2.5/weather?id=4032243&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #51:3618908 Juigalpa, NI
# ---------------------------------------------------------------------------
# Now retieving city # 33
# https://api.openweathermap.org/data/2.5/weather?id=3618908&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #52:3369157 Cape Town, ZA
# ---------------------------------------------------------------------------
# Now retieving city # 34
# https://api.openweathermap.org/data/2.5/weather?id=3369157&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #53:2014078 Urusha, RU
# ---------------------------------------------------------------------------
# Now retieving city # 35
# https://api.openweathermap.org/data/2.5/weather?id=2014078&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #54:667306 Sfantu Gheorghe, RO
# ---------------------------------------------------------------------------
# Now retieving city # 36
# https://api.openweathermap.org/data/2.5/weather?id=667306&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #55:3439208 Capiibary, PY
# ---------------------------------------------------------------------------
# Now retieving city # 37
# https://api.openweathermap.org/data/2.5/weather?id=3439208&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #57:1649150 Bengkulu, ID
# ---------------------------------------------------------------------------
# Now retieving city # 38
# https://api.openweathermap.org/data/2.5/weather?id=1649150&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #58:2071860 Esperance, AU
# ---------------------------------------------------------------------------
# Now retieving city # 39
# https://api.openweathermap.org/data/2.5/weather?id=2071860&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
#
# ********Sleeping for 70.63695764541626 seconds.********
#
# Now retrieving data for city id #61:2033536 Yakeshi, CN
# ---------------------------------------------------------------------------
# Now retieving city # 40
# https://api.openweathermap.org/data/2.5/weather?id=2033536&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #64:53654 Mogadishu, SO
# ---------------------------------------------------------------------------
# Now retieving city # 41
# https://api.openweathermap.org/data/2.5/weather?id=53654&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #66:3184575 Orikum, AL
# ---------------------------------------------------------------------------
# Now retieving city # 42
# https://api.openweathermap.org/data/2.5/weather?id=3184575&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #67:6185377 Yellowknife, CA
# ---------------------------------------------------------------------------
# Now retieving city # 43
# https://api.openweathermap.org/data/2.5/weather?id=6185377&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #71:2084442 Vanimo, PG
# ---------------------------------------------------------------------------
# Now retieving city # 44
# https://api.openweathermap.org/data/2.5/weather?id=2084442&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #72:2163355 Hobart, AU
# ---------------------------------------------------------------------------
# Now retieving city # 45
# https://api.openweathermap.org/data/2.5/weather?id=2163355&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #74:3932145 Pisco, PE
# ---------------------------------------------------------------------------
# Now retieving city # 46
# https://api.openweathermap.org/data/2.5/weather?id=3932145&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #76:241131 Victoria, SC
# ---------------------------------------------------------------------------
# Now retieving city # 47
# https://api.openweathermap.org/data/2.5/weather?id=241131&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #77:3870243 Taltal, CL
# ---------------------------------------------------------------------------
# Now retieving city # 48
# https://api.openweathermap.org/data/2.5/weather?id=3870243&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #78:5855927 Hilo, US
# ---------------------------------------------------------------------------
# Now retieving city # 49
# https://api.openweathermap.org/data/2.5/weather?id=5855927&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
#
# ********Sleeping for 67.8572347164154 seconds.********
#
# Now retrieving data for city id #79:5848280 Kapaa, US
# ---------------------------------------------------------------------------
# Now retieving city # 50
# https://api.openweathermap.org/data/2.5/weather?id=5848280&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #80:2629833 Husavik, IS
# ---------------------------------------------------------------------------
# Now retieving city # 51
# https://api.openweathermap.org/data/2.5/weather?id=2629833&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #81:2016405 Smolenka, RU
# ---------------------------------------------------------------------------
# Now retieving city # 52
# https://api.openweathermap.org/data/2.5/weather?id=2016405&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #83:934322 Mahebourg, MU
# ---------------------------------------------------------------------------
# Now retieving city # 53
# https://api.openweathermap.org/data/2.5/weather?id=934322&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #84:5258190 Juneau, US
# ---------------------------------------------------------------------------
# Now retieving city # 54
# https://api.openweathermap.org/data/2.5/weather?id=5258190&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #88:1015776 Bredasdorp, ZA
# ---------------------------------------------------------------------------
# Now retieving city # 55
# https://api.openweathermap.org/data/2.5/weather?id=1015776&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #89:1282256 Hithadhoo, MV
# ---------------------------------------------------------------------------
# Now retieving city # 56
# https://api.openweathermap.org/data/2.5/weather?id=1282256&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #90:3896218 Castro, CL
# ---------------------------------------------------------------------------
# Now retieving city # 57
# https://api.openweathermap.org/data/2.5/weather?id=3896218&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #91:2121385 Severo-Kurilsk, RU
# ---------------------------------------------------------------------------
# Now retieving city # 58
# https://api.openweathermap.org/data/2.5/weather?id=2121385&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #92:6167817 Torbay, CA
# ---------------------------------------------------------------------------
# Now retieving city # 59
# https://api.openweathermap.org/data/2.5/weather?id=6167817&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
#
# ********Sleeping for 77.9272985458374 seconds.********
# Now retrieving data for city id #93:2126199 Cherskiy, RU
# ---------------------------------------------------------------------------
# Now retieving city # 60
# https://api.openweathermap.org/data/2.5/weather?id=2126199&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #94:2017155 Saskylakh, RU
# ---------------------------------------------------------------------------
# Now retieving city # 61
# https://api.openweathermap.org/data/2.5/weather?id=2017155&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #95:587207 Artyom, AZ
# ---------------------------------------------------------------------------
# Now retieving city # 62
# https://api.openweathermap.org/data/2.5/weather?id=587207&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #98:2015306 Tiksi, RU
# ---------------------------------------------------------------------------
# Now retieving city # 63
# https://api.openweathermap.org/data/2.5/weather?id=2015306&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #99:1049261 Chimoio, MZ
# ---------------------------------------------------------------------------
# Now retieving city # 64
# https://api.openweathermap.org/data/2.5/weather?id=1049261&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #101:216449 Gandajika, CD
# ---------------------------------------------------------------------------
# Now retieving city # 65
# https://api.openweathermap.org/data/2.5/weather?id=216449&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #102:1506938 Erzin, RU
# ---------------------------------------------------------------------------
# Now retieving city # 66
# https://api.openweathermap.org/data/2.5/weather?id=1506938&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #103:4133367 Texarkana, US
# ---------------------------------------------------------------------------
# Now retieving city # 67
# https://api.openweathermap.org/data/2.5/weather?id=4133367&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #106:3883457 Lebu, CL
# ---------------------------------------------------------------------------
# Now retieving city # 68
# https://api.openweathermap.org/data/2.5/weather?id=3883457&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #109:2013279 Vostok, RU
# ---------------------------------------------------------------------------
# Now retieving city # 69
# https://api.openweathermap.org/data/2.5/weather?id=2013279&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
#
# ********Sleeping for 72.03509259223938 seconds.********
#
# Now retrieving data for city id #111:2022463 Khilok, RU
# ---------------------------------------------------------------------------
# Now retieving city # 70
# https://api.openweathermap.org/data/2.5/weather?id=2022463&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #112:5000947 Marquette, US
# ---------------------------------------------------------------------------
# Now retieving city # 71
# https://api.openweathermap.org/data/2.5/weather?id=5000947&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #113:304854 Manavgat, TR
# ---------------------------------------------------------------------------
# Now retieving city # 72
# https://api.openweathermap.org/data/2.5/weather?id=304854&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #114:2025630 Chara, RU
# ---------------------------------------------------------------------------
# Now retieving city # 73
# https://api.openweathermap.org/data/2.5/weather?id=2025630&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #115:3366880 Hermanus, ZA
# ---------------------------------------------------------------------------
# Now retieving city # 74
# https://api.openweathermap.org/data/2.5/weather?id=3366880&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #116:4920512 Fremont, US
# ---------------------------------------------------------------------------
# Now retieving city # 75
# https://api.openweathermap.org/data/2.5/weather?id=4920512&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #123:4031574 Provideniya, RU
# ---------------------------------------------------------------------------
# Now retieving city # 76
# https://api.openweathermap.org/data/2.5/weather?id=4031574&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #124:3860443 Comodoro Rivadavia, AR
# ---------------------------------------------------------------------------
# Now retieving city # 77
# https://api.openweathermap.org/data/2.5/weather?id=3860443&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #125:986717 Kruisfontein, ZA
# ---------------------------------------------------------------------------
# Now retieving city # 78
# https://api.openweathermap.org/data/2.5/weather?id=986717&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #126:5850554 Makakilo City, US
# ---------------------------------------------------------------------------
# Now retieving city # 79
# https://api.openweathermap.org/data/2.5/weather?id=5850554&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
#
# ********Sleeping for 72.38113474845886 seconds.********
#
# Now retrieving data for city id #127:2013258 Vrangel, RU
# ---------------------------------------------------------------------------
# Now retieving city # 80
# https://api.openweathermap.org/data/2.5/weather?id=2013258&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #129:2126123 Chokurdakh, RU
# ---------------------------------------------------------------------------
# Now retieving city # 81
# https://api.openweathermap.org/data/2.5/weather?id=2126123&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #131:3984997 San Quintin, MX
# ---------------------------------------------------------------------------
# Now retieving city # 82
# https://api.openweathermap.org/data/2.5/weather?id=3984997&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #132:1817240 Baiyin, CN
# ---------------------------------------------------------------------------
# Now retieving city # 83
# https://api.openweathermap.org/data/2.5/weather?id=1817240&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #134:1293625 Dawei, MM
# ---------------------------------------------------------------------------
# Now retieving city # 84
# https://api.openweathermap.org/data/2.5/weather?id=1293625&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #135:2446796 Bilma, NE
# ---------------------------------------------------------------------------
# Now retieving city # 85
# https://api.openweathermap.org/data/2.5/weather?id=2446796&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #136:1259385 Port Blair, IN
# ---------------------------------------------------------------------------
# Now retieving city # 86
# https://api.openweathermap.org/data/2.5/weather?id=1259385&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #140:777019 Vardo, NO
# ---------------------------------------------------------------------------
# Now retieving city # 87
# https://api.openweathermap.org/data/2.5/weather?id=777019&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #141:2030065 Mandalgovi, MN
# ---------------------------------------------------------------------------
# Now retieving city # 88
# https://api.openweathermap.org/data/2.5/weather?id=2030065&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #142:1058381 Morondava, MG
# ---------------------------------------------------------------------------
# Now retieving city # 89
# https://api.openweathermap.org/data/2.5/weather?id=1058381&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
#
# ********Sleeping for 71.61418676376343 seconds.********
# Now retrieving data for city id #143:2281120 Tabou, CI
# ---------------------------------------------------------------------------
# Now retieving city # 90
# https://api.openweathermap.org/data/2.5/weather?id=2281120&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #144:2158767 Mareeba, AU
# ---------------------------------------------------------------------------
# Now retieving city # 91
# https://api.openweathermap.org/data/2.5/weather?id=2158767&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #146:2513222 Nijar, ES
# ---------------------------------------------------------------------------
# Now retieving city # 92
# https://api.openweathermap.org/data/2.5/weather?id=2513222&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #147:286245 Sur, OM
# ---------------------------------------------------------------------------
# Now retieving city # 93
# https://api.openweathermap.org/data/2.5/weather?id=286245&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #148:4035715 Avarua, CK
# ---------------------------------------------------------------------------
# Now retieving city # 94
# https://api.openweathermap.org/data/2.5/weather?id=4035715&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #149:5374920 Morro Bay, US
# ---------------------------------------------------------------------------
# Now retieving city # 95
# https://api.openweathermap.org/data/2.5/weather?id=5374920&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #150:2122090 Pevek, RU
# ---------------------------------------------------------------------------
# Now retieving city # 96
# https://api.openweathermap.org/data/2.5/weather?id=2122090&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #151:5972762 Hay River, CA
# ---------------------------------------------------------------------------
# Now retieving city # 97
# https://api.openweathermap.org/data/2.5/weather?id=5972762&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #152:4013679 Coahuayana, MX
# ---------------------------------------------------------------------------
# Now retieving city # 98
# https://api.openweathermap.org/data/2.5/weather?id=4013679&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #153:4034551 Faanui, PF
# ---------------------------------------------------------------------------
# Now retieving city # 99
# https://api.openweathermap.org/data/2.5/weather?id=4034551&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
#
# ********Sleeping for 77.81060528755188 seconds.********
#
# Now retrieving data for city id #156:3522526 Nuevo Progreso, MX
# ---------------------------------------------------------------------------
# Now retieving city # 100
# https://api.openweathermap.org/data/2.5/weather?id=3522526&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #157:1494523 Polovinnoye, RU
# ---------------------------------------------------------------------------
# Now retieving city # 101
# https://api.openweathermap.org/data/2.5/weather?id=1494523&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #161:2022572 Khatanga, RU
# ---------------------------------------------------------------------------
# Now retieving city # 102
# https://api.openweathermap.org/data/2.5/weather?id=2022572&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #162:2729907 Longyearbyen, SJ
# ---------------------------------------------------------------------------
# Now retieving city # 103
# https://api.openweathermap.org/data/2.5/weather?id=2729907&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #163:1563926 Tra Vinh, VN
# ---------------------------------------------------------------------------
# Now retieving city # 104
# https://api.openweathermap.org/data/2.5/weather?id=1563926&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #164:5880054 Barrow, US
# ---------------------------------------------------------------------------
# Now retieving city # 105
# https://api.openweathermap.org/data/2.5/weather?id=5880054&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #168:2780579 Ebbs, AT
# ---------------------------------------------------------------------------
# Now retieving city # 106
# https://api.openweathermap.org/data/2.5/weather?id=2780579&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #169:5861897 Fairbanks, US
# ---------------------------------------------------------------------------
# Now retieving city # 107
# https://api.openweathermap.org/data/2.5/weather?id=5861897&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #171:1863997 Fukue, JP
# ---------------------------------------------------------------------------
# Now retieving city # 108
# https://api.openweathermap.org/data/2.5/weather?id=1863997&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #172:4026082 Lazaro Cardenas, MX
# ---------------------------------------------------------------------------
# Now retieving city # 109
# https://api.openweathermap.org/data/2.5/weather?id=4026082&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
#
# ********Sleeping for 77.58321475982666 seconds.********
#
# Now retrieving data for city id #173:1538639 Solnechnyy, RU
# ---------------------------------------------------------------------------
# Now retieving city # 110
# https://api.openweathermap.org/data/2.5/weather?id=1538639&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #177:1275435 Biswan, IN
# ---------------------------------------------------------------------------
# Now retieving city # 111
# https://api.openweathermap.org/data/2.5/weather?id=1275435&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #178:4334720 Natchitoches, US
# ---------------------------------------------------------------------------
# Now retieving city # 112
# https://api.openweathermap.org/data/2.5/weather?id=4334720&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #179:2126682 Bilibino, RU
# ---------------------------------------------------------------------------
# Now retieving city # 113
# https://api.openweathermap.org/data/2.5/weather?id=2126682&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #180:3412093 Vestmannaeyjar, IS
# ---------------------------------------------------------------------------
# Now retieving city # 114
# https://api.openweathermap.org/data/2.5/weather?id=3412093&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #181:3460087 Jardim, BR
# ---------------------------------------------------------------------------
# Now retieving city # 115
# https://api.openweathermap.org/data/2.5/weather?id=3460087&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #184:3489440 Morant Bay, JM
# ---------------------------------------------------------------------------
# Now retieving city # 116
# https://api.openweathermap.org/data/2.5/weather?id=3489440&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #185:915471 Kalabo, ZM
# ---------------------------------------------------------------------------
# Now retieving city # 117
# https://api.openweathermap.org/data/2.5/weather?id=915471&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #187:2422465 Conakry, GN
# ---------------------------------------------------------------------------
# Now retieving city # 118
# https://api.openweathermap.org/data/2.5/weather?id=2422465&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #189:556268 Ostrovnoy, RU
# ---------------------------------------------------------------------------
# Now retieving city # 119
# https://api.openweathermap.org/data/2.5/weather?id=556268&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
#
# ********Sleeping for 77.5332760810852 seconds.********
# Now retrieving data for city id #190:6100799 Pemberton, CA
# ---------------------------------------------------------------------------
# Now retieving city # 120
# https://api.openweathermap.org/data/2.5/weather?id=6100799&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #191:3424934 Saint-Pierre, PM
# ---------------------------------------------------------------------------
# Now retieving city # 121
# https://api.openweathermap.org/data/2.5/weather?id=3424934&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #192:3650273 Velasco Ibarra, EC
# ---------------------------------------------------------------------------
# Now retieving city # 122
# https://api.openweathermap.org/data/2.5/weather?id=3650273&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #193:889191 Karoi, ZW
# ---------------------------------------------------------------------------
# Now retieving city # 123
# https://api.openweathermap.org/data/2.5/weather?id=889191&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #196:1071296 Antalaha, MG
# ---------------------------------------------------------------------------
# Now retieving city # 124
# https://api.openweathermap.org/data/2.5/weather?id=1071296&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #197:2990474 Nevers, FR
# ---------------------------------------------------------------------------
# Now retieving city # 125
# https://api.openweathermap.org/data/2.5/weather?id=2990474&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #198:5871146 Palmer, US
# ---------------------------------------------------------------------------
# Now retieving city # 126
# https://api.openweathermap.org/data/2.5/weather?id=5871146&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #201:1529660 Aksu, CN
# ---------------------------------------------------------------------------
# Now retieving city # 127
# https://api.openweathermap.org/data/2.5/weather?id=1529660&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #202:3691954 Sechura, PE
# ---------------------------------------------------------------------------
# Now retieving city # 128
# https://api.openweathermap.org/data/2.5/weather?id=3691954&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #203:2965649 Castleblayney, IE
# ---------------------------------------------------------------------------
# Now retieving city # 129
# https://api.openweathermap.org/data/2.5/weather?id=2965649&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
#
# ********Sleeping for 77.82756471633911 seconds.********
#
# Now retrieving data for city id #204:3457708 Marica, BR
# ---------------------------------------------------------------------------
# Now retieving city # 130
# https://api.openweathermap.org/data/2.5/weather?id=3457708&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #206:582447 Almaznyy, RU
# ---------------------------------------------------------------------------
# Now retieving city # 131
# https://api.openweathermap.org/data/2.5/weather?id=582447&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #208:3380290 Sinnamary, GF
# ---------------------------------------------------------------------------
# Now retieving city # 132
# https://api.openweathermap.org/data/2.5/weather?id=3380290&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #209:3394539 Montes Altos, BR
# ---------------------------------------------------------------------------
# Now retieving city # 133
# https://api.openweathermap.org/data/2.5/weather?id=3394539&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #212:5855051 Ewa Beach, US
# ---------------------------------------------------------------------------
# Now retieving city # 134
# https://api.openweathermap.org/data/2.5/weather?id=5855051&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #214:5880568 Bethel, US
# ---------------------------------------------------------------------------
# Now retieving city # 135
# https://api.openweathermap.org/data/2.5/weather?id=5880568&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #220:2024626 Dzhebariki-Khaya, RU
# ---------------------------------------------------------------------------
# Now retieving city # 136
# https://api.openweathermap.org/data/2.5/weather?id=2024626&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #223:1631637 Pemangkat, ID
# ---------------------------------------------------------------------------
# Now retieving city # 137
# https://api.openweathermap.org/data/2.5/weather?id=1631637&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #224:1514792 Gazojak, TM
# ---------------------------------------------------------------------------
# Now retieving city # 138
# https://api.openweathermap.org/data/2.5/weather?id=1514792&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #225:2522325 Aguimes, ES
# ---------------------------------------------------------------------------
# Now retieving city # 139
# https://api.openweathermap.org/data/2.5/weather?id=2522325&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
#
# ********Sleeping for 77.85548806190491 seconds.********
#
# Now retrieving data for city id #228:3391287 Prainha, BR
# ---------------------------------------------------------------------------
# Now retieving city # 140
# https://api.openweathermap.org/data/2.5/weather?id=3391287&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #229:2937317 Diepholz, DE
# ---------------------------------------------------------------------------
# Now retieving city # 141
# https://api.openweathermap.org/data/2.5/weather?id=2937317&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #230:3489657 Lucea, JM
# ---------------------------------------------------------------------------
# Now retieving city # 142
# https://api.openweathermap.org/data/2.5/weather?id=3489657&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #233:610298 Beyneu, KZ
# ---------------------------------------------------------------------------
# Now retieving city # 143
# https://api.openweathermap.org/data/2.5/weather?id=610298&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #234:1855540 Naze, JP
# ---------------------------------------------------------------------------
# Now retieving city # 144
# https://api.openweathermap.org/data/2.5/weather?id=1855540&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #235:3381041 Mana, GF
# ---------------------------------------------------------------------------
# Now retieving city # 145
# https://api.openweathermap.org/data/2.5/weather?id=3381041&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #236:5563839 Fortuna, US
# ---------------------------------------------------------------------------
# Now retieving city # 146
# https://api.openweathermap.org/data/2.5/weather?id=5563839&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #237:3383570 Marienburg, SR
# ---------------------------------------------------------------------------
# Now retieving city # 147
# https://api.openweathermap.org/data/2.5/weather?id=3383570&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #238:4004293 Ixtapa, MX
# ---------------------------------------------------------------------------
# Now retieving city # 148
# https://api.openweathermap.org/data/2.5/weather?id=4004293&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #242:1250161 Batticaloa, LK
# ---------------------------------------------------------------------------
# Now retieving city # 149
# https://api.openweathermap.org/data/2.5/weather?id=1250161&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
#
# ********Sleeping for 77.27670192718506 seconds.********
# Now retrieving data for city id #245:3529654 Dzilam Gonzalez, MX
# ---------------------------------------------------------------------------
# Now retieving city # 150
# https://api.openweathermap.org/data/2.5/weather?id=3529654&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #247:780643 Bjornevatn, NO
# ---------------------------------------------------------------------------
# Now retieving city # 151
# https://api.openweathermap.org/data/2.5/weather?id=780643&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #248:1175012 Kandiari, PK
# ---------------------------------------------------------------------------
# Now retieving city # 152
# https://api.openweathermap.org/data/2.5/weather?id=1175012&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #249:5423573 Grand Junction, US
# ---------------------------------------------------------------------------
# Now retieving city # 153
# https://api.openweathermap.org/data/2.5/weather?id=5423573&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #250:2181625 Te Anau, NZ
# ---------------------------------------------------------------------------
# Now retieving city # 154
# https://api.openweathermap.org/data/2.5/weather?id=2181625&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #251:1625908 Sungairaya, ID
# ---------------------------------------------------------------------------
# Now retieving city # 155
# https://api.openweathermap.org/data/2.5/weather?id=1625908&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #252:2173323 Bundaberg, AU
# ---------------------------------------------------------------------------
# Now retieving city # 156
# https://api.openweathermap.org/data/2.5/weather?id=2173323&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #254:1636308 Manokwari, ID
# ---------------------------------------------------------------------------
# Now retieving city # 157
# https://api.openweathermap.org/data/2.5/weather?id=1636308&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #255:6144312 Sept-Iles, CA
# ---------------------------------------------------------------------------
# Now retieving city # 158
# https://api.openweathermap.org/data/2.5/weather?id=6144312&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #256:2160517 Launceston, AU
# ---------------------------------------------------------------------------
# Now retieving city # 159
# https://api.openweathermap.org/data/2.5/weather?id=2160517&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
#
# ********Sleeping for 77.97688913345337 seconds.********
#
# Now retrieving data for city id #257:343292 Asosa, ET
# ---------------------------------------------------------------------------
# Now retieving city # 160
# https://api.openweathermap.org/data/2.5/weather?id=343292&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #258:3985710 Cabo San Lucas, MX
# ---------------------------------------------------------------------------
# Now retieving city # 161
# https://api.openweathermap.org/data/2.5/weather?id=3985710&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #261:2399371 Makokou, GA
# ---------------------------------------------------------------------------
# Now retieving city # 162
# https://api.openweathermap.org/data/2.5/weather?id=2399371&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #262:2294206 Wa, GH
# ---------------------------------------------------------------------------
# Now retieving city # 163
# https://api.openweathermap.org/data/2.5/weather?id=2294206&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #263:2112309 Katsuura, JP
# ---------------------------------------------------------------------------
# Now retieving city # 164
# https://api.openweathermap.org/data/2.5/weather?id=2112309&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #265:3466174 Cianorte, BR
# ---------------------------------------------------------------------------
# Now retieving city # 165
# https://api.openweathermap.org/data/2.5/weather?id=3466174&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #268:1847947 Shingu, JP
# ---------------------------------------------------------------------------
# Now retieving city # 166
# https://api.openweathermap.org/data/2.5/weather?id=1847947&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #270:2645753 Kettering, GB
# ---------------------------------------------------------------------------
# Now retieving city # 167
# https://api.openweathermap.org/data/2.5/weather?id=2645753&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #273:878281 Lindi, TZ
# ---------------------------------------------------------------------------
# Now retieving city # 168
# https://api.openweathermap.org/data/2.5/weather?id=878281&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #274:726050 Varna, BG
# ---------------------------------------------------------------------------
# Now retieving city # 169
# https://api.openweathermap.org/data/2.5/weather?id=726050&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
#
# ********Sleeping for 77.85490274429321 seconds.********
#
# Now retrieving data for city id #275:863061 Usinsk, RU
# ---------------------------------------------------------------------------
# Now retieving city # 170
# https://api.openweathermap.org/data/2.5/weather?id=863061&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #276:653252 Kempele, FI
# ---------------------------------------------------------------------------
# Now retieving city # 171
# https://api.openweathermap.org/data/2.5/weather?id=653252&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #277:2077895 Alice Springs, AU
# ---------------------------------------------------------------------------
# Now retieving city # 172
# https://api.openweathermap.org/data/2.5/weather?id=2077895&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #278:2027296 Aykhal, RU
# ---------------------------------------------------------------------------
# Now retieving city # 173
# ...
# ---------------------------------------------------------------------------
# Now retieving city # 431
# https://api.openweathermap.org/data/2.5/weather?id=1783745&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #661:779554 Honningsvag, NO
# ---------------------------------------------------------------------------
# Now retieving city # 432
# https://api.openweathermap.org/data/2.5/weather?id=779554&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #662:5955902 Fort Nelson, CA
# ---------------------------------------------------------------------------
# Now retieving city # 433
# https://api.openweathermap.org/data/2.5/weather?id=5955902&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #664:335035 Harer, ET
# ---------------------------------------------------------------------------
# Now retieving city # 434
# https://api.openweathermap.org/data/2.5/weather?id=335035&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #666:2622139 Fjerritslev, DK
# ---------------------------------------------------------------------------
# Now retieving city # 435
# https://api.openweathermap.org/data/2.5/weather?id=2622139&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #667:287832 Ibra, OM
# ---------------------------------------------------------------------------
# Now retieving city # 436
# https://api.openweathermap.org/data/2.5/weather?id=287832&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #669:189741 Lamu, KE
# ---------------------------------------------------------------------------
# Now retieving city # 437
# https://api.openweathermap.org/data/2.5/weather?id=189741&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #670:1142264 Farah, AF
# ---------------------------------------------------------------------------
# Now retieving city # 438
# https://api.openweathermap.org/data/2.5/weather?id=1142264&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #671:3389822 Salinopolis, BR
# ---------------------------------------------------------------------------
# Now retieving city # 439
# https://api.openweathermap.org/data/2.5/weather?id=3389822&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
#
# ********Sleeping for 77.83220672607422 seconds.********
#
# Now retrieving data for city id #672:1633034 Palu, ID
# ---------------------------------------------------------------------------
# Now retieving city # 440
# https://api.openweathermap.org/data/2.5/weather?id=1633034&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #674:1265452 Kushalgarh, IN
# ---------------------------------------------------------------------------
# Now retieving city # 441
# https://api.openweathermap.org/data/2.5/weather?id=1265452&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #675:901344 Ndola, ZM
# ---------------------------------------------------------------------------
# Now retieving city # 442
# https://api.openweathermap.org/data/2.5/weather?id=901344&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #676:1487241 Verkh-Tula, RU
# ---------------------------------------------------------------------------
# Now retieving city # 443
# https://api.openweathermap.org/data/2.5/weather?id=1487241&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #677:3868210 Vilcun, CL
# ---------------------------------------------------------------------------
# Now retieving city # 444
# https://api.openweathermap.org/data/2.5/weather?id=3868210&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #678:1727201 Banhigan, PH
# ---------------------------------------------------------------------------
# Now retieving city # 445
# https://api.openweathermap.org/data/2.5/weather?id=1727201&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #679:1045114 Inhambane, MZ
# ---------------------------------------------------------------------------
# Now retieving city # 446
# https://api.openweathermap.org/data/2.5/weather?id=1045114&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #683:605155 Kiruna, SE
# ---------------------------------------------------------------------------
# Now retieving city # 447
# https://api.openweathermap.org/data/2.5/weather?id=605155&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #685:2438855 Tera, NE
# ---------------------------------------------------------------------------
# Now retieving city # 448
# https://api.openweathermap.org/data/2.5/weather?id=2438855&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #686:1852357 Shimoda, JP
# ---------------------------------------------------------------------------
# Now retieving city # 449
# https://api.openweathermap.org/data/2.5/weather?id=1852357&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
#
# ********Sleeping for 77.78591656684875 seconds.********
# Now retrieving data for city id #687:5849996 Lahaina, US
# ---------------------------------------------------------------------------
# Now retieving city # 450
# https://api.openweathermap.org/data/2.5/weather?id=5849996&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #688:560191 Gordeyevka, RU
# ---------------------------------------------------------------------------
# Now retieving city # 451
# https://api.openweathermap.org/data/2.5/weather?id=560191&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #689:3577430 Road Town, VG
# ---------------------------------------------------------------------------
# Now retieving city # 452
# https://api.openweathermap.org/data/2.5/weather?id=3577430&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #690:321191 Beysehir, TR
# ---------------------------------------------------------------------------
# Now retieving city # 453
# https://api.openweathermap.org/data/2.5/weather?id=321191&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #691:3542744 Ranchuelo, CU
# ---------------------------------------------------------------------------
# Now retieving city # 454
# https://api.openweathermap.org/data/2.5/weather?id=3542744&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #693:2450849 Sokolo, ML
# ---------------------------------------------------------------------------
# Now retieving city # 455
# https://api.openweathermap.org/data/2.5/weather?id=2450849&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #695:2412778 Kuntaur, GM
# ---------------------------------------------------------------------------
# Now retieving city # 456
# https://api.openweathermap.org/data/2.5/weather?id=2412778&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #697:5712169 Baker City, US
# ---------------------------------------------------------------------------
# Now retieving city # 457
# https://api.openweathermap.org/data/2.5/weather?id=5712169&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #698:5983720 Iqaluit, CA
# ---------------------------------------------------------------------------
# Now retieving city # 458
# https://api.openweathermap.org/data/2.5/weather?id=5983720&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #699:4031742 Egvekinot, RU
# ---------------------------------------------------------------------------
# Now retieving city # 459
# https://api.openweathermap.org/data/2.5/weather?id=4031742&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
#
# ********Sleeping for 77.84942317008972 seconds.********
#
# Now retrieving data for city id #701:2316748 Bolobo, CD
# ---------------------------------------------------------------------------
# Now retieving city # 460
# https://api.openweathermap.org/data/2.5/weather?id=2316748&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #703:1731298 Aloleng, PH
# ---------------------------------------------------------------------------
# Now retieving city # 461
# https://api.openweathermap.org/data/2.5/weather?id=1731298&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #706:4015076 Casas Grandes, MX
# ---------------------------------------------------------------------------
# Now retieving city # 462
# https://api.openweathermap.org/data/2.5/weather?id=4015076&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #707:4351871 Clinton, US
# ---------------------------------------------------------------------------
# Now retieving city # 463
# https://api.openweathermap.org/data/2.5/weather?id=4351871&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #727:162158 Baherden, TM
# ---------------------------------------------------------------------------
# Now retieving city # 464
# https://api.openweathermap.org/data/2.5/weather?id=162158&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #728:1259243 Punalur, IN
# ---------------------------------------------------------------------------
# Now retieving city # 465
# https://api.openweathermap.org/data/2.5/weather?id=1259243&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #729:2120591 Tilichiki, RU
# ---------------------------------------------------------------------------
# Now retieving city # 466
# https://api.openweathermap.org/data/2.5/weather?id=2120591&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #730:522775 Nelidovo, RU
# ---------------------------------------------------------------------------
# Now retieving city # 467
# https://api.openweathermap.org/data/2.5/weather?id=522775&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #731:2234339 Betare Oya, CM
# ---------------------------------------------------------------------------
# Now retieving city # 468
# https://api.openweathermap.org/data/2.5/weather?id=2234339&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #732:2015913 Suntar, RU
# ---------------------------------------------------------------------------
# Now retieving city # 469
# https://api.openweathermap.org/data/2.5/weather?id=2015913&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
#
# ********Sleeping for 77.79761028289795 seconds.********
#
# Now retrieving data for city id #733:218680 Boende, CD
# ---------------------------------------------------------------------------
# Now retieving city # 470
# https://api.openweathermap.org/data/2.5/weather?id=218680&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #734:1519422 Semey, KZ
# ---------------------------------------------------------------------------
# Now retieving city # 471
# https://api.openweathermap.org/data/2.5/weather?id=1519422&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #735:103630 Najran, SA
# ---------------------------------------------------------------------------
# Now retieving city # 472
# https://api.openweathermap.org/data/2.5/weather?id=103630&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #736:3372783 Ponta Delgada, PT
# ---------------------------------------------------------------------------
# Now retieving city # 473
# https://api.openweathermap.org/data/2.5/weather?id=3372783&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #737:893485 Chiredzi, ZW
# ---------------------------------------------------------------------------
# Now retieving city # 474
# https://api.openweathermap.org/data/2.5/weather?id=893485&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #738:3664525 Codajas, BR
# ---------------------------------------------------------------------------
# Now retieving city # 475
# https://api.openweathermap.org/data/2.5/weather?id=3664525&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #739:1862505 Hirara, JP
# ---------------------------------------------------------------------------
# Now retieving city # 476
# https://api.openweathermap.org/data/2.5/weather?id=1862505&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #742:1793364 Tangping, CN
# ---------------------------------------------------------------------------
# Now retieving city # 477
# https://api.openweathermap.org/data/2.5/weather?id=1793364&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #743:3393536 Olinda, BR
# ---------------------------------------------------------------------------
# Now retieving city # 478
# https://api.openweathermap.org/data/2.5/weather?id=3393536&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #744:1040652 Maputo, MZ
# ---------------------------------------------------------------------------
# Now retieving city # 479
# https://api.openweathermap.org/data/2.5/weather?id=1040652&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
#
# ********Sleeping for 77.83622241020203 seconds.********
# Now retrieving data for city id #745:703537 Kuteynykove, UA
# ---------------------------------------------------------------------------
# Now retieving city # 480
# https://api.openweathermap.org/data/2.5/weather?id=703537&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #746:3652758 Puerto Baquerizo Moreno, EC
# ---------------------------------------------------------------------------
# Now retieving city # 481
# https://api.openweathermap.org/data/2.5/weather?id=3652758&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #748:3936456 Lima, PE
# ---------------------------------------------------------------------------
# Now retieving city # 482
# https://api.openweathermap.org/data/2.5/weather?id=3936456&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #750:3386177 Trairi, BR
# ---------------------------------------------------------------------------
# Now retieving city # 483
# https://api.openweathermap.org/data/2.5/weather?id=3386177&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #751:3465713 Conde, BR
# ---------------------------------------------------------------------------
# Now retieving city # 484
# https://api.openweathermap.org/data/2.5/weather?id=3465713&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #754:2520493 Calvia, ES
# ---------------------------------------------------------------------------
# Now retieving city # 485
# https://api.openweathermap.org/data/2.5/weather?id=2520493&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #755:1626493 Srandakan, ID
# ---------------------------------------------------------------------------
# Now retieving city # 486
# https://api.openweathermap.org/data/2.5/weather?id=1626493&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #756:3571913 Marsh Harbour, BS
# ---------------------------------------------------------------------------
# Now retieving city # 487
# https://api.openweathermap.org/data/2.5/weather?id=3571913&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial
# Now retrieving data for city id #757:3466165 Cidreira, BR
# ---------------------------------------------------------------------------
# Now retieving city # 488
# https://api.openweathermap.org/data/2.5/weather?id=3466165&appid=5580baaefa2bed44aa5e1d152e482231&units=Imperial

# %%
print(current_error_list)
# Out:
# []

# %%
weather_data
# Out:
#                         city country       id        lat         lon  \
# 0                New Norfolk      AU  2155415 -42.782612  147.058701
# 3                     Knysna      ZA   988698 -34.036270   23.047131
# 4                  Sembabule      UG   226361  -0.077220   31.456671
# 5             Saint-Philippe      RE   935215 -21.358521   55.767948
# 7                     Beloha      MG  1067565 -25.166670   45.049999
# 8                   Klaksvik      FO  2618795  62.226551   -6.589010
# 10                      Tura      RU  2014833  64.283333  100.250000
# 11                 Busselton      AU  2075265 -33.650002  115.333328
# 12                 Carnarvon      AU  2074865 -24.866671  113.633331
# 13                 Wattegama      LK  1224061   6.798900   81.480797
# 15                Sao Filipe      CV  3374210  14.896100  -24.495560
# 18                  Coquimbo      CL  3893629 -29.953329  -71.343613
# 19               East London      ZA  1006984 -33.015289   27.911619
# 21                     Tobol      KZ  1518139  52.684441   62.579441
# 22                   Ushuaia      AR  3833367 -54.799999  -68.300003
# 23                  Lorengau      PG  2092164  -2.022590  147.271194
# 26                  Suraabad      AZ   584991  40.819241   49.468739
# 27                  Waycross      US  4229763  31.213551  -82.354019
# 29               Port Alfred      ZA   964432 -33.590569   26.891041
# 30                    Albany      AU  2077963 -35.016941  117.891670
# 32                 Grindavik      IS  3416888  63.842400  -22.433750
# 34              Puerto Ayora      EC  3652764  -0.739310  -90.351761
# 36                 Jamestown      SH  3370903 -15.938720   -5.716750
# 37               Peace River      CA  6100069  56.250099 -117.285988
# 38                Hinesville      US  4200671  31.846880  -81.595947
# 39              Punta Arenas      CL  3874787 -53.150002  -70.916672
# 40             Krasnoyarskiy      RU   542133  51.965000   59.896671
# 41                 Dongsheng      CN  1812256  39.816078  109.977631
# 44                    Motema      SL  2405038   8.600000  -11.033330
# 45                    Sorong      ID  1626542  -0.883330  131.250000
# ..                       ...     ...      ...        ...         ...
# 699                Egvekinot      RU  4031742  66.316673 -179.166672
# 701                   Bolobo      CD  2316748  -2.166670   16.233330
# 703                  Aloleng      PH  1731298  16.130699  119.782402
# 706            Casas Grandes      MX  4015076  30.366671 -107.949997
# 707                  Clinton      US  4351871  38.765110  -76.898308
# 727                 Baherden      TM   162158  38.436241   57.431580
# 728                  Punalur      IN  1259243   9.000000   76.933327
# 729                Tilichiki      RU  2120591  60.466671  166.100006
# 730                 Nelidovo      RU   522775  56.221069   32.777382
# 731               Betare Oya      CM  2234339   5.600000   14.083330
# 732                   Suntar      RU  2015913  62.144440  117.631943
# 733                   Boende      CD   218680  -0.216670   20.866671
# 734                    Semey      KZ  1519422  50.411110   80.227501
# 735                   Najran      SA   103630  17.492399   44.127659
# 736            Ponta Delgada      PT  3372783  37.733330  -25.666670
# 737                 Chiredzi      ZW   893485 -21.049999   31.666670
# 738                  Codajas      BR  3664525  -3.836670  -62.056938
# 739                   Hirara      JP  1862505  24.799999  125.283333
# 742                 Tangping      CN  1793364  22.026470  111.932289
# 743                   Olinda      BR  3393536  -8.008890  -34.855282
# 744                   Maputo      MZ  1040652 -25.965281   32.589169
# 745              Kuteynykove      UA   703537  47.812271   38.288219
# 746  Puerto Baquerizo Moreno      EC  3652758  -0.900000  -89.599998
# 748                     Lima      PE  3936456 -12.043180  -77.028236
# 750                   Trairi      BR  3386177  -3.277780  -39.268890
# 751                    Conde      BR  3465713 -11.813610  -37.610561
# 754                   Calvia      ES  2520493  39.565701    2.506210
# 755                Srandakan      ID  1626493  -7.938610  110.250557
# 756            Marsh Harbour      BS  3571913  26.541241  -77.063599
# 757                 Cidreira      BR  3466165 -30.181110  -50.205559
#
#     current_temp  current_humidity  current_clouds current_wind
# 0           57.2                58              75         6.93
# 3           55.4                71              75          4.7
# 4          64.35                94              80         5.17
# 5          76.03                50               0         6.93
# 7          67.59                80               0         6.51
# 8           48.2               100              92        14.99
# 10         62.82                62              44         5.28
# 11         61.74               100              56         4.16
# 12         70.11                74              44        13.11
# 13         88.02                66               0        15.46
# 15         72.18               100               0           13
# 18            50                93              75         2.24
# 19            59                44               0         6.93
# 21         67.77                47              36        14.23
# 22         29.07               100              80         8.63
# 23         84.87                99              20         4.83
# 26          82.4                51               0         8.05
# 27         78.12                94               1         5.82
# 29         60.12                95               0        12.77
# 30         58.59                87              92         3.71
# 32          46.4                87              75        17.22
# 34         70.74               100              44         9.64
# 36         70.02               100              92        18.48
# 37            68                64              75          4.7
# 38         80.92                74               1         6.17
# 39            32               100              75        23.04
# 40         66.42                42              48        17.69
# 41          70.2                94              64         6.06
# 44         70.02                96              92         6.85
# 45         78.12               100              44         7.52
# ..           ...               ...             ...          ...
# 699        56.25                31               0         4.72
# 701        70.65                95               8         1.59
# 703         83.7               100              64         5.95
# 706         64.8                45               0         2.48
# 707        73.17                78              90        10.29
# 727        87.39                37               0         6.17
# 728         80.6                83              75         6.93
# 729         55.8                75               0         5.17
# 730        73.44                64              80        19.71
# 731        66.24               100              88         3.94
# 732        71.82                58              36         3.94
# 733        68.76               100              92         3.04
# 734        87.57                34               0         9.53
# 735         89.6                13               0         9.17
# 736         62.6                93              40         8.05
# 737        59.49                85               0         2.93
# 738           72                96              36         1.92
# 739        86.92                79              75        19.46
# 742        85.59                79              68         9.75
# 743         78.8                61              20        12.75
# 744         64.4                82               0         8.05
# 745        85.77                24               0         9.98
# 746        72.36               100              68        10.98
# 748        50.94                80               8         1.36
# 750        80.82                99              12        21.72
# 751        76.05                84             100         6.96
# 754         73.4                73               0         2.24
# 755        82.53                75              80         8.97
# 756        82.44               100               0         9.31
# 757        53.64                89              20        10.87
#
# [489 rows x 9 columns]

# %%
weather_data.to_csv("WeatherData.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-18-ee0382b82c92> in <module>()
# ----> 1 weather_data.to_csv("WeatherData.csv", index=False)
#
# ~\AppData\Local\conda\conda\envs\pythondata\lib\site-packages\pandas\core\frame.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, tupleize_cols, date_format, doublequote, escapechar, decimal)
#    1522                                      doublequote=doublequote,
#    1523                                      escapechar=escapechar, decimal=decimal)
# -> 1524         formatter.save()
#    1525
#    1526         if path_or_buf is None:
#
# ~\AppData\Local\conda\conda\envs\pythondata\lib\site-packages\pandas\io\formats\format.py in save(self)
#    1635             f, handles = _get_handle(self.path_or_buf, self.mode,
#    1636                                      encoding=encoding,
# -> 1637                                      compression=self.compression)
#    1638             close = True
#    1639
#
# ~\AppData\Local\conda\conda\envs\pythondata\lib\site-packages\pandas\io\common.py in _get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text)
#     388         elif encoding:
#     389             # Python 3 and encoding
# --> 390             f = open(path_or_buf, mode, encoding=encoding)
#     391         elif is_text:
#     392             # Python 3 and no explicit encoding
#
# PermissionError: [Errno 13] Permission denied: 'WeatherData.csv'

# %%
plt.scatter(weather_data["lat"],weather_data["current_temp"], alpha = 0.5)

plt.title("Temperature (F) vs. Latitude Date of Analysis 06-21-2018")
plt.xlabel("Latitude")
plt.ylabel("Temperature (F)")
plt.savefig("Temperature_Vs_Latitude.png")
plt.show()

# %%
plt.scatter(weather_data["lat"],weather_data["current_humidity"], alpha = 0.75)

plt.title("Latitude vs. Humidity Date of Analysis 06-21-2018")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.savefig("Humidity_Vs_Latitude.png")
plt.show()

# %%
plt.scatter(weather_data["lat"],weather_data["current_clouds"], alpha = 0.75)

plt.title("Latitude vs.Cloudiness Date of Analysis 06-21-2018")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.savefig("Cloudiness_Vs_Latitude.png")
plt.show()

# %%
plt.scatter(weather_data["lat"],weather_data["current_wind"], alpha= 0.75)
plt.title("Latitude vs Wind Speed Date of Analysis 06-21-2018")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.savefig("Wind Speed_vs_Latitude.png")
plt.show()

# %%
plt.scatter(weather_data["lon"],weather_data["lat"])
plt.title("Longitude vs Latitude")
plt.ylabel("Latitude")
plt.xlabel("Longitude")
plt.savefig("Longitude_vs_Latitude.png")
plt.show()
